# %%
import sys
import os
import getopt
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.lines import Line2D
from matplotlib import animation
from IPython.display import Image

#global options
pylab.rcParams['figure.figsize'] = 16, 12
fig = plt.figure()
ax = plt.axes(xlim=(0, 400), ylim=(0, 400))
line, = ax.plot([], [], lw=2)

# %%
def oneNode(opt, fileName):
  """plot one node"""
  ax = fig.add_subplot(1,1,1)
  a = np.loadtxt(str(fileName[1]))
  x = a[:,0]
  y = a[:,1]
  ax.plot(x,y,'--')
  if opt == 1:
    plt.show()

# %%
def allNodesIn(cwd):
  """plots all the .visplotX files found in the given dir
  """
  legendList = []
  print("found the following:")
  for argument in os.listdir(cwd):
    if 'visplot' in argument:
      oneNode(2,[1,str(cwd)+"/"+argument])
      print(str(cwd)+"/"+argument)
      legendList.append(str(argument))
  ax = fig.add_subplot(1,1,1)
  ax.legend(legendList)
  plt.draw()
  plt.show()

# %%
def allNodes(fileName):
  """plots all the nodes, the input is the decompressed file produced by bm"""
  fig1 = plt.figure()
  ax1 = plt.axes(xlim=(0, 400), ylim=(0, 400))
  line, = ax1.plot([], [], lw=2)
    
  f = open(str(fileName[1]))
  i = 0
  nodes = [] 
  for line in f:
    nodes.append(line)
    i += 1
  print("totalNodes: "+str(len(nodes)))
  
  nodeContainer = [] #contains all the nodes
  for index in range(i):
    #initialize all the nodes to zero
    node = np.zeros((len(nodes[index].split())/3,3))
    nodeContainer.append(node)

    
  indexOfNodes = 0
  listOfCoords = []

  for element in nodes:
    indexOfCoords = 0
    #list of the coordenates of node "element" as [t0,x0,y0,t1...]
    listOfCoords = element.split()
    i = 0 #line of an specific node, so: [tn,xn,yn]
    while indexOfCoords != len(listOfCoords):
      nodeContainer[indexOfNodes][i][0] = listOfCoords[indexOfCoords]
      nodeContainer[indexOfNodes][i][1] = listOfCoords[indexOfCoords + 1]
      nodeContainer[indexOfNodes][i][2] = listOfCoords[indexOfCoords + 2]
      indexOfCoords += 3
      i += 1
    indexOfNodes += 1
  ax1 = fig1.add_subplot(1,1,1)
  legendList = []
  for i in range(len(nodeContainer)):
    ax1.plot(nodeContainer[i][:,1],nodeContainer[i][:,2], '--')
    legendList.append(str(i))
  for j in range(len(nodeContainer[0][:,1])):
    #annotates time in each data point for the first node
    ax.annotate(str(nodeContainer[0][j][0]), (nodeContainer[0][j][1],nodeContainer[0][j][2]))  
  legend(legendList)
  #plt.show()

# %% [markdown]
# ## Reference Point Group Movement

# %% [markdown]
# #### ./bm -f rpgm RPGM -n 6 -d 900 -i 3600

# %%
allNodes([1,"/home/default/workspace/bonnmotion-2.1/bin/rpgm.movements"])
# Out:
# totalNodes: 6

# %% [markdown]
# ## Disaster Area

# %% [markdown]
# #### https://github.com/matiya/bonn-motion-parser/blob/master/scriptDisaster.pl

# %% [raw]
# In catastrophe situations, the users of communication systems that need reliable communication are civil protection forces,
# including rescue teams and fire brigades. These forces are strictly structured and their actions are strictly organised.
# The units do not walk around randomly. There is one leader or a group of leaders (technical operational command ) which
# tells everybody where and how to move or in which area to work. In general, the movements are driven by tac tical reasons.
# These tactics are based on a method called separation of the room. The disaster area and its surrounding is divided into
# different areas: incident site, casualties treatment area, transport zone, and hospital zone (cf. figure 1).

# %%
Image(filename='figure_3.png')

# %% [raw]
# The incident site is the place where the disaster actually happened. In this area affected and injured people as well as fatalities
# are found and the disaster (e.g. fire) has to be minimised. The affected and injured people are brought to the casualties
# treatment area. The casualties treatment area consists of two places: the patients waiting for treatment area and the casualties
# clearing station. The patients waiting for treatment area is usually close to the incident site. The people are rescued from danger
# and wait there for their treatment.Then they are transported to the casualties clearing station which is still within the disaster
# area. After an extended first aid they are transported to hospital. The transport zone is an area where transport units
# (ambulance coaches and rescue helicopters) wait in stand-by areas to take these people to hospitals. The technical operational command
# is usually located in the casualties treatment area as well.

# %%
allNodesIn("/home/default/workspace/bonnmotion-2.1/bin/")
# Out:
# found the following:
# /home/default/workspace/bonnmotion-2.1/bin//DA.visplot7
# /home/default/workspace/bonnmotion-2.1/bin//DA.visplot6
# /home/default/workspace/bonnmotion-2.1/bin//DA.visplot2
# /home/default/workspace/bonnmotion-2.1/bin//DA.visplot10
# /home/default/workspace/bonnmotion-2.1/bin//DA.visplot4
# /home/default/workspace/bonnmotion-2.1/bin//DA.visplot8
# /home/default/workspace/bonnmotion-2.1/bin//DA.visplot0
# /home/default/workspace/bonnmotion-2.1/bin//DA.visplot3
# /home/default/workspace/bonnmotion-2.1/bin//DA.visplot1
# /home/default/workspace/bonnmotion-2.1/bin//DA.visplot9
# /home/default/workspace/bonnmotion-2.1/bin//DA.visplot11
# /home/default/workspace/bonnmotion-2.1/bin//DA.visplot12
# /home/default/workspace/bonnmotion-2.1/bin//DA.visplot5

# %%
Image(filename='figure_1.png', width=1200, height= 1000)

# %% [raw]
# This is the output (as given by the simulator) based on the following scenario (except that there are 13 nodes and one clearing station):

# %%
Image(filename='figure_2.png')

# %% [markdown]
# ## RandomWaypoint w/Attraction

# %% [markdown]
# #### ./bm -f rwattraction RandomWaypoint -n 6 -h 1 -d 900 -i 3600 -x 300 -y 300 -0 1 -a 10,10,1,20,20,10,290,1.5,31,35

# %%
allNodes([1,"/home/default/workspace/bonnmotion-2.1/bin/rwattraction.movements"])
# Out:
# totalNodes: 6

# %% [markdown]
# Migth be improved by defining starting coords

# %% [markdown]
# ## Random Street

# %% [markdown]
# #### ./bm -f randomstreet RandomStreet -p ../doc/RaSt_example/RaSt_parameter.txt -d 1500 -i 3000 -n 10

# %%
allNodes([1,"/home/default/workspace/bonnmotion-2.1/bin/randomstreet.movements"])
# Out:
# totalNodes: 10

# %% [markdown]
# ## Manhattan Grid

# %% [markdown]
# #### ./bm -f manhattan ManhattanGrid -n 6 -d 900 -i 3600 -u 3 -v 2

# %%
allNodes([1,"/home/default/workspace/bonnmotion-2.1/bin/manhattan.movements"])
# Out:
# totalNodes: 6

# %% [markdown]
# ## Column

# %% [raw]
# A group mobility model where the set of MNs form a line and are uniformly moving forward in a particular direction.
# In this model the user will specify the number of node and number of groups.

# %% [markdown]
# ### Two Groups

# %% [markdown]
# #### ./bm -f column Column -d 900 -i 200 -n 8 -x 300 -y 300 -a 2 -r 2 -s 10

# %%
allNodes([1,"/home/default/workspace/bonnmotion-2.1/bin/column.movements"])
# Out:
# totalNodes: 8

# %% [markdown]
# ### One Group

# %% [markdown]
# #### ./bm -f column Column -d 900 -i 200 -n 8 -x 300 -y 300 -a 1 -r 2 -s 10

# %%
allNodes([1,"/home/default/workspace/bonnmotion-2.1/bin/column2.movements"])
# Out:
# totalNodes: 8

# %% [markdown]
# ## Steady State Random Waypoint

# %% [markdown]
# #### ./bm -f steady SteadyStateRandomWaypoint -d 900 -i 0 -n 8 -x 300 -y 300 -o 3 -p 2

# %%
allNodes([1,"/home/default/workspace/bonnmotion-2.1/bin/steady.movements"])
# Out:
# totalNodes: 8
